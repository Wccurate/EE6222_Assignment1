# %% [markdown]
# # EE6222 DR Results Demo\n读取某次实验 run 目录并重绘核心曲线。

# %%
from pathlib import Path\nimport pandas as pd\nfrom ee6222_dr.viz.curves import plot_from_run_dir\n\n# 修改为你的 run 目录\nrun_dir = Path('outputs/runs/ee6222_dr_quick_YYYYMMDD_HHMMSS')\nresults = pd.read_csv(run_dir / 'results_long.csv')\nresults.head()

# %%
paths = plot_from_run_dir(run_dir)\npaths
